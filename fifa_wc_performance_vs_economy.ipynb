# %%
import pandas
# %matplotlib inline
import matplotlib.pyplot as plt
fifa_raw_data = '/Users/tejasbon/Documents/delete/fifa.tsv'
fifa_df = pandas.read_csv(fifa_raw_data, encoding='utf-8', delimiter='\t')

# %%
headers = list(fifa_df)
correlations = list()
for i in headers[1:]:
    for j in headers[2:]:
        if i is not j:
            correlation = fifa_df[i].corr(fifa_df[j])
            if correlation < 0:
                correlation = 0 - correlation
            correlations.append((correlation, 'correlation between '+ i + ' and '+ j + ' is = ' + str(correlation)))
            fifa_df.plot.scatter(x=i, y=j)
correlations.sort(key=lambda tup: tup[0], reverse=True)
# Out:
# /Users/tejasbon/miniconda3/envs/dnnService/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
fifa_df
# Out:
#             Team  HDI Rank  Human Development Index  \
# 0      Argentina        45                    0.827
# 1      Australia         3                    0.939
# 2        Belgium        21                    0.896
# 3         Brazil        79                    0.754
# 4       Columbia        95                    0.727
# 5      Costarica        66                    0.776
# 6        Croatia        46                    0.827
# 7        Denmark         6                    0.925
# 8          Egypt       111                    0.691
# 9        England        16                    0.909
# 10        France        22                    0.897
# 11       Germany         4                    0.926
# 12       Iceland         9                    0.921
# 13          IRAN        68                    0.774
# 14         Japan        17                    0.903
# 15         Korea        18                    0.901
# 16        Mexico        77                    0.762
# ...

# %%
# colored plot
N = len(fifa_df)
cmap = plt.cm.get_cmap("hsv", N+1)
for i in range(N):
    X, Y = fifa_df.iloc[i][['FIFA Rank (current)', 'HDI Rank']]
    plt.scatter(X, Y, cmap(i))
